# %% [markdown]
# # 情報論A 中間課題用テンプレ
#
# ---
# ---
#
# ## 課題説明
# 中間試験に代わる、レポートを兼ねた演習課題です。自由に取り組みましょう。
#
# ## 条件
# これまでに講義で解説した、あるいは演習で取り組んだ内容をもとに、自由に問題を決め、それを解く実装を作ってください。条件は以下の通りです：
# - 問題を自分で考えること
# - データを自分で集めること
# - 問題の解法の部分は、できるだけ自分で実装すること。例えば：
#   - `np.linalg.solve`のような高級な関数ではなく、自分で疑似逆行列を計算する
#   - `scipy.optimize.minimize`のような高級な関数ではなく、自分で勾配を計算してiterationを回す
# - 講義で説明した解法や、それに関連する方法を使って解くこと
#   - 逆に言えば、そういう問題に落とし込めるような問題を考えると良いです
#
# ## 望ましい条件
# - 独創的な問題を考えること
# - 実装が`ipynb` (Jupyter Notebook)であること
#   - そうできない場合は個別にご相談ください
#   - 動作はGoogle Colabを前提にしてもしなくても良いです。動作環境をメタデータに記載してください。
#
# ## その他
# - 必ずしも「結果が良い」必要はありません。解法に至る過程がある程度妥当で、実装が正しければ問題ないです。結果が悪いのも重要な知見です。
#
# ## LLMポリシー
# LLM（ChatGPTなど）を使うことは妨げませんが、あくまで「自分の頭を使った部分」が採点基準になります。ですので、LLMなどを使う場合は、下記「LLM usage declaration」で、どこにどのように使ったかを明記してください。
#
# ## 採点基準
# 「自分の頭を使ってやった部分」を対象に、以下を総合的に評価します。
# - 問題の独創性とデータの独自性
# - 解法の妥当性
# - 実装の正確さ
# - レポート記述の充実性
#
# ---
# ---

# %% [markdown]
# # 提出メタデータ
# テキストセルは、ダブルクリックすると編集できます
#
# ## 提出者情報
# ```
# 氏名：
# 学籍番号：
# ```
#
# ## プログラミング・動作環境
# 下記と異なる場合は、適宜変更してください。Google Colab上で動かない場合は、OSとPythonのバージョン、追加が必要なライブラリを書いていただけるとありがたいです。
# ```
# プログラミング環境: Python + Jupyter Notebook (.ipynb)
# 動作環境: Google Colaboratory
# ```
#
# ## LLM usage declaration
# LLMを使った場合、以下で*どこにどのように使ったか*を明記すること。事実と異なる報告をした場合、本課題の得点を0点とする。
# ```
# ***ここに記述***
# ```
#
# ---
# ---

# %% [markdown]
# # レポート部分
#
# 以下に、どのような思いで、何を作ったかをマークダウン形式で書いてください。分量は自由ですが、無駄に長くする必要はありません。注釈は消してください。
#
# （作ったものの背景にある思いみたいなものも、独自性に含みますので、何かあればぜひ書いてください。）
#
# ---
#
# ## タイトル
# *何か良い感じのタイトル*
#
# ## 背景
# *今回作ったものの社会的・技術的・個人的背景を書いてください。*
#
# ## 問題の概要
# *なにが入力で、何が出力なのか書いてください*
#
# ## 解法の概要
# *どのように解いたか書いてください。できれば、マークダウン形式で数式を書いてもらえると更に良いです*
#
# 数式の例：
# $$
# y_i\mathbf{w}^T\mathbf{x}_i > 0
# $$
#
# ## 結果と考察
# *結果がどうだった、とかパラメータを変えるとどうなるか、とか考察があれば書いてください。*
#
# ---
# ---

# %% [markdown]
# # 実装部分
#
# 以下は自由に使ってください。補足があれば、適宜テキストセルに書き込むなどしてください。

# %% [markdown]
# ### 準備
#
# ライブラリのインポートなど

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Googleドライブをマウントする場合
# from google.colab import drive
# drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/johoronA/"
